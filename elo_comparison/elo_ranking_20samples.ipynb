# %% [markdown]
# ### Import everything

# %%
import os
import json
import pandas as pd

# %% [markdown]
# ### Read in JSONS

# %%
def read_json_files(file_names):
    data = []
    for file_name in file_names:
        with open(file_name, 'r') as file:
            data.append(json.load(file))
    return data

# read everyone's elo comparison files
file_names = ["comparison_jsons/elo/h1_elo.json", 
              "comparison_jsons/elo/h6_elo.json", "comparison_jsons/elo/h7_elo.json", "comparison_jsons/elo/h5_elo.json", 
              "comparison_jsons/elo/h4_elo.json", "comparison_jsons/elo/h3_elo.json", "comparison_jsons/elo/h2_elo.json"]
data = read_json_files(file_names)

# %% [markdown]
# ### Separate all twenty sample sentences into separate DFs

# %%
# labelers
labelers = ['llama2', 'llama3', 'mistral', 'Human1', 'Human2', 'Human3', 'Human4', 'Human5', 'Human6', 'Human7']

# sentences and IDs: this was the way I wanted to do it
sample_sentences = {
    1: "It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.",
    2: "The prompt acceleration of food aid pledges and deliveries once the media story on the famine broke, even though the worst of the crisis was over by then, and the poorer response to non-food emergency needs, which received less press attention, lends weight to another familiar hypothesis: that one of these non-humanitarian criteria is media pressure.",
    3: "Some men were hesitant to assist with household chores because they believed it would create an expectation of ongoing involvement with chores after pregnancy.",
    4: "Pastoralists in the arid and semi-arid regions of Mali continue to face increasing risk due to low levels of rainfall.",
    5: "The recent investment in improving existing roads that connect administrative centres to regional capitals, combined with the advance in use of mobile phone communications, have facilitated the development of new and efficient cereal trade routes and reduced marketing margins.",
    6: "Wind turbine foundations may act as artificial reefs, which could increase both the number of shellfish and the animals that feed on them, including other fish and marine mammals.",
    7: "However, wars have been waged to reduce demographic pressures arising from the scarcity of arable land, the clearest example being the move to acquire Lebensraum (living space) that motivated Nazi Germany aggression toward Poland and Eastern Europe.",
    8: "The direct and indirect effects from offshore wind farm development have been less well documented, but they include similar risks to bird and bat collisions; disruption of marine mammal corridors as well as harm to marine mammals, fish, and sea turtles from construction of bottom-mounted turbine towers; the potential for scour and sediment resuspension around the foundations of bottom-mounted wind turbines; and some evidence of displacement or barrier effects because of the presence of large offshore wind farms.",
    9: "The study shows that the cultivation of crops, a critical aspect of food security, is gravely under threat given low cultivation of crops as a result of BH atrocities.",
    10: "Various sources attest that elevated mortality stemming from conflict is due more to population displacement, deficiencies of clean water and sanitation, exposure to disease, and public-health failures rather than to direct blows from violence.",
    11: "Civilians may also expand agricultural production due to cuts in a stable food supply.",
    12: "The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out elsewhere (1996), the failure of these programmes has to do with the fact that in spite of the majority of them targeting farming, the serious structural crisis the agricultural sector was undergoing was underestimated in their design and implementation.",
    13: "On the supply side, both Huthi/Saleh forces and the Hadi government and its Saudi-led coalition allies repeatedly have hindered the movement of aid and commercial goods to the population. Huthi/Saleh violations are most egregious in the city of Taiz, where their fighters have enforced a full or partial blockade since 2015, with devastating humanitarian consequences. They routinely interfere with the work of humanitarians, at times demanding the diversion of aid to themselves or denying aid workers access to populations in need, revoking visas or even detaining them. They heavily tax all imports into their areas in part to finance the war effort and also run a black market in fuel, enriching military elites while driving prices up for transport of vital commodities.",
    14: "Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.",
    15: "Borrowing food was observed to be the first step to mitigate the adverse effect of food insecurity at the household level in Yemen.",
    16: "ASHA must tell the woman during pregnancy so that the woman must have that information with her. So, as soon as the child takes birth he/she will be fed with colostrum which will prevent the child from diseases.",
    17: "For me, when I got married and my wife was pregnant, I registered her in general hospital, and also in a traditional Centre. Because my understanding is that, there are medications in the hospital and also another type of medications from the traditional.",
    18: "Even, we do not want to be uncovered so that our private parts do not be seen.",
    19: "The use of contraception was linked vicariously to promiscuity: Promiscuous women were linked to the use of contraception, multiple abortions and disease or infections.",
    20: "I had vaginal discharge four months ago and I used a traditional medicine it stopped."
}

# separate data for each sample sentence
sentence_data = {sentence_id: [] for sentence_id in sample_sentences.keys()}
for file_data in data:
    print(file_data)
    for key, value in file_data.items():
        sentence_text, labelers_pair, sentence_id, winner = value
        if sentence_id in sample_sentences.keys():
            sentence_data[sentence_id].append(value)
# Out:
# {'0': ['Pastoralists in the arid and semi-arid regions of Mali continue to face increasing risk due to low levels of rainfall.', ['Human6', 'mistral'], 4, 'Human6'], '1': ['The prompt acceleration of food aid pledges and deliveries once the media story on the famine broke, even though the worst of the crisis was over by then, and the poorer response to non-food emergency needs, which received less press attention, lends weight to another familiar hypothesis: that one of these non-humanitarian criteria is media pressure.', ['Human7', 'Human2'], 2, 'Human2'], '2': ['For me, when I got married and my wife was pregnant, I registered her in general hospital, and also in a traditional Centre. Because my understanding is that, there are medications in the hospital and also another type of medications from the traditional.', ['Human6', 'Human4'], 17, 'Human6'], '3': ['The direct and indirect effects from offshore wind farm development have been less well documented, but they include similar risks to bird and bat collisions [16,17]; disruption of marine mammal corridors [15] as well as harm to marine mammals, fish, and sea turtles from construction of bottom-mounted turbine towers [18]; the potential for scour and sediment resuspension around the foundations of bottom-mounted wind turbines [19]; and some evidence of displacement or barrier effects because of the presence of large offshore wind farms.', ['Human5', 'llama2'], 8, 'llama2'], '4': ['Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.', ['Human6', 'llama3'], 14, 'Human6'], '5': ['The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out elsewhere (1996), the failure of these programmes has to do with the fact that in spite of the majority of them targeting farming, the serious structural crisis the agricultural sector was undergoing was underestimated in their design and implementation.', ['Human4', 'Human6'], 12, 'Human6'], '6': ['Various sources attest that elevated mortality stemming from conflict is due more to population displacement, deficiencies of clean water and sanitation, exposure to disease, and public-health failures rather than to direct blows from violence.', ['llama3', 'llama2'], 10, 'llama3'], '7': ['Borrowing food was observed to be the first step to mitigate the adverse effect of food insecurity at the household level in Yemen.', ['Human6', 'Human2'], 15, 'Tie'], '8': ['The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out elsewhere (1996), the failure of these programmes has to do with the fact that in spite of the majority of them targeting farming, the serious structural crisis the agricultural sector was undergoing was underestimated in their design and implementation.', ['Human3', 'Human4'], 12, 'Human4'], '9': ['The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out elsewhere (1996), the failure of these programmes has to do with the fact that in spite of the majority of them targeting farming, the serious structural crisis the agricultural sector was undergoing was underestimated in their design and implementation.', ['Human5', 'Human6'], 12, 'Human6'], '10': ['The prompt acceleration of food aid pledges and deliveries once the media story on the famine broke, even though the worst of the crisis was over by then, and the poorer response to non-food emergency nee ...
# {'0': ['The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out elsewhere (1996), the failure of these programmes has to do with the fact that in spite of the majority of them targeting farming, the serious structural crisis the agricultural sector was undergoing was underestimated in their design and implementation.', ['llama2', 'mistral'], 12, 'mistral'], '1': ['For me, when I got married and my wife was pregnant, I registered her in general hospital, and also in a traditional Centre. Because my understanding is that, there are medications in the hospital and also another type of medications from the traditional.', ['Human5', 'llama3'], 17, 'llama3'], '2': ['Wind turbine foundations may act as artificial reefs, which could increase both the number of shellfish and the animals that feed on them, including other fish and marine mammals.', ['Human3', 'llama3'], 6, 'Human3'], '3': ['I had vaginal discharge four months ago and I used a traditional medicine it stopped.', ['Human3', 'Human4'], 20, 'Tie'], '4': ['Even, we do not want to be uncovered so that our private parts do not be seen.', ['Human7', 'Human5'], 18, 'Human7'], '5': ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.', ['Human3', 'Human4'], 1, 'Human3'], '6': ['The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out elsewhere (1996), the failure of these programmes has to do with the fact that in spite of the majority of them targeting farming, the serious structural crisis the agricultural sector was undergoing was underestimated in their design and implementation.', ['Human2', 'llama2'], 12, 'Human2'], '7': ['For me, when I got married and my wife was pregnant, I registered her in general hospital, and also in a traditional Centre. Because my understanding is that, there are medications in the hospital and also another type of medications from the traditional.', ['Human3', 'Human1'], 17, 'Human3'], '8': ['The recent investment in improving existing roads that connect administrative centres to regional capitals, combined with the advance in use of mobile phone communications, have facilitated the development of new and efficient cereal trade routes and reduced marketing margins.', ['Human1', 'mistral'], 5, 'Human1'], '9': ['The recent investment in improving existing roads that connect administrative centres to regional capitals, combined with the advance in use of mobile phone communications, have facilitated the development of new and efficient cereal trade routes and reduced marketing margins.', ['llama2', 'Human5'], 5, 'Human5'], '10': ['The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out elsewhere (1996), the failure of these programmes has to do with the fact that in spite of the majority of them targeting farming, the serious structural crisis the agricultural sector was undergoing was underestimated in their design and implementation.', ['Human5', 'Human3'], 12, 'Human3'], '11': ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.', ['mistral', 'llama2'], 1, 'mistral'], '12': ['Some men were hesitant to assist with household chores because they believed it would create an expectation of  ...
# {'0': ['Wind turbine foundations may act as artificial reefs, which could increase both the number of shellfish and the animals that feed on them, including other fish and marine mammals.', ['llama3', 'Human1'], 6, 'Tie'], '1': ['The direct and indirect effects from offshore wind farm development have been less well documented, but they include similar risks to bird and bat collisions [16,17]; disruption of marine mammal corridors [15] as well as harm to marine mammals, fish, and sea turtles from construction of bottom-mounted turbine towers [18]; the potential for scour and sediment resuspension around the foundations of bottom-mounted wind turbines [19]; and some evidence of displacement or barrier effects because of the presence of large offshore wind farms.', ['Human3', 'llama2'], 8, 'Human3'], '2': ['Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.', ['Human4', 'mistral'], 14, 'mistral'], '3': ['Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.', ['Human4', 'Human1'], 14, 'Human4'], '4': ['Borrowing food was observed to be the first step to mitigate the adverse effect of food insecurity at the household level in Yemen.', ['mistral', 'Human1'], 15, 'Human1'], '5': ['Some men were hesitant to assist with household chores because they believed it would create an expectation of ongoing involvement with chores after pregnancy.', ['Human5', 'Human1'], 3, 'Human5'], '6': ['Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.', ['llama3', 'Human3'], 14, 'llama3'], '7': ['The recent investment in improving existing roads that connect administrative centres to regional capitals, combined with the advance in use of mobile phone communications, have facilitated the development of new and efficient cereal trade routes and reduced marketing margins.', ['Human2', 'Human3'], 5, 'Human2'], '8': ['Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.', ['Human1', 'Human3'], 14, 'Tie'], '9': ['However, wars have been waged to reduce demographic pressures arising from the scarcity of arable land, the clearest example being the move to acquire Lebensraum (living space) that motivated Nazi Germany aggression toward Poland and Eastern Europe.', ['Human1', 'Human6'], 7, 'Human6'], '10': ['Pastoralists in the arid and semi-arid regions of Mali continue to face increasing risk due to low levels of rainfall.', ['Human2', 'Human3'], 4, 'Tie'], '11': ['For me, when I got married and my wife was pregnant, I registered her in general hospital, and also in a traditional Centre. Because my understanding is that, there are medications in the hospital and also another type of medications from the traditional.', ['Human2', 'Human6'], 17, 'Human6'], '12': ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.', ['Human1', 'Human3'], 1, 'Human3'], '13': ['Wind turbine foundations may act as artificial reefs, which could increase both the number of shellfish and the animals that feed on them, including other fish and marine mammals.', ['Human3', 'Human5'], 6, 'Human3'], '14': ['The use of contraception was linked vicariously to promiscuity: Promiscuous women were linked to the use of contraception, multiple abortions and disease or infections.', ['mistral', 'Human5'], 19, 'Human5'], '15': ['Various sources attest that elevated mortality stemming from conflict is due more to population displacement, deficiencies of clean water and sanitation, exposure to disease, and public-health failures rather than to direct blows from violence.', ['llama2', 'Human5'], 10, 'Human5'],  ...
# {'0': ['For me, when I got married and my wife was pregnant, I registered her in general hospital, and also in a traditional Centre. Because my understanding is that, there are medications in the hospital and also another type of medications from the traditional.', ['mistral', 'Human1'], 17, 'Human1'], '1': ['Civilians may also expand agricultural production due to cuts in a stable food supply.', ['llama3', 'Human3'], 11, 'llama3'], '2': ['ASHA must tell the woman during pregnancy so that the woman must have that information with her. So, as soon as the child takes birth he/she will be fed with colostrum which will prevent the child from diseases.', ['Human1', 'Human3'], 16, 'Tie'], '3': ['The prompt acceleration of food aid pledges and deliveries once the media story on the famine broke, even though the worst of the crisis was over by then, and the poorer response to non-food emergency needs, which received less press attention, lends weight to another familiar hypothesis: that one of these non-humanitarian criteria is media pressure.', ['Human4', 'Human3'], 2, 'Human4'], '4': ['Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.', ['llama3', 'Human1'], 14, 'llama3'], '5': ['I had vaginal discharge four months ago and I used a traditional medicine it stopped.', ['llama2', 'Human4'], 20, 'Tie'], '6': ['The direct and indirect effects from offshore wind farm development have been less well documented, but they include similar risks to bird and bat collisions [16,17]; disruption of marine mammal corridors [15] as well as harm to marine mammals, fish, and sea turtles from construction of bottom-mounted turbine towers [18]; the potential for scour and sediment resuspension around the foundations of bottom-mounted wind turbines [19]; and some evidence of displacement or barrier effects because of the presence of large offshore wind farms.', ['llama2', 'Human7'], 8, 'Human7'], '7': ['Even, we do not want to be uncovered so that our private parts do not be seen.', ['Human4', 'Human3'], 18, 'Human4'], '8': ['The recent investment in improving existing roads that connect administrative centres to regional capitals, combined with the advance in use of mobile phone communications, have facilitated the development of new and efficient cereal trade routes and reduced marketing margins.', ['Human4', 'Human2'], 5, 'Human4'], '9': ['The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out elsewhere (1996), the failure of these programmes has to do with the fact that in spite of the majority of them targeting farming, the serious structural crisis the agricultural sector was undergoing was underestimated in their design and implementation.', ['Human2', 'llama3'], 12, 'llama3'], '10': ['Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.', ['Human1', 'mistral'], 14, 'mistral'], '11': ['ASHA must tell the woman during pregnancy so that the woman must have that information with her. So, as soon as the child takes birth he/she will be fed with colostrum which will prevent the child from diseases.', ['Human2', 'Human3'], 16, 'Human2'], '12': ['ASHA must tell the woman during pregnancy so that the woman must have that information with her. So, as soon as the child takes birth he/she will be fed with colostrum which will prevent the child from diseases.', ['Human7', 'llama3'], 16, 'Human7'], '13': ['For me, when I got married and my wife was pregnant, I registered her in general hospital, and also in a traditional Centre. Because my understanding is that, there are medications in the hospital and also another type of medications from the traditional.', ['Human1', 'Human6'], ...
# {'0': ['Wind turbine foundations may act as artificial reefs, which could increase both the number of shellfish and the animals that feed on them, including other fish and marine mammals.', ['Human6', 'llama3'], 6, 'Human6'], '1': ['The study shows that the cultivation of crops, a critical aspect of food security, is gravely under threat given low cultivation of crops as a result of BH atrocities.', ['llama3', 'Human2'], 9, 'Tie'], '2': ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.', ['Human1', 'Human2'], 1, 'Human1'], '3': ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.', ['Human5', 'Human1'], 1, 'Human1'], '4': ['Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.', ['Human1', 'Human7'], 14, 'Human1'], '5': ['However, wars have been waged to reduce demographic pressures arising from the scarcity of arable land, the clearest example being the move to acquire Lebensraum (living space) that motivated Nazi Germany aggression toward Poland and Eastern Europe.', ['llama2', 'Human7'], 7, 'Tie'], '6': ['Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.', ['mistral', 'llama3'], 14, 'Tie'], '7': ['Borrowing food was observed to be the first step to mitigate the adverse effect of food insecurity at the household level in Yemen.', ['Human5', 'mistral'], 15, 'Human5'], '8': ['Some men were hesitant to assist with household chores because they believed it would create an expectation of ongoing involvement with chores after pregnancy.', ['Human2', 'mistral'], 3, 'Human2'], '9': ['Increased grievances against the state, when agricultural deficits at the state level result in losses of tax revenues and higher food prices.', ['Human1', 'Human6'], 14, 'Human6'], '10': ['Borrowing food was observed to be the first step to mitigate the adverse effect of food insecurity at the household level in Yemen.', ['Human6', 'Human5'], 15, 'Tie'], '11': ['Various sources attest that elevated mortality stemming from conflict is due more to population displacement, deficiencies of clean water and sanitation, exposure to disease, and public-health failures rather than to direct blows from violence.', ['Human3', 'llama2'], 10, 'Human3'], '12': ['However, wars have been waged to reduce demographic pressures arising from the scarcity of arable land, the clearest example being the move to acquire Lebensraum (living space) that motivated Nazi Germany aggression toward Poland and Eastern Europe.', ['llama2', 'llama3'], 7, 'llama2'], '13': ['On the supply side, both Huthi/Saleh forces and the Hadi government and its Saudi-led coalition allies repeatedly have hindered the movement of aid and commercial goods to the population. Huthi/Saleh violations are most egregious in the city of Taiz, where their fighters have enforced a full or partial blockade since 2015, with devastating humanitarian consequences. They routinely interfere with the work of humanitarians, at times demanding the diversion of aid to themselves or denying aid workers access to populations in need, revoking visas or even detaining them. They heavily tax all imports into their areas in part to finance the war effort and also run a black market in fuel, enriching military elites while driving prices up for transport of vital commodities.', ['Human1', 'Human7'], 13, 'Human1'], '14': ['The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out else ...
# {'0': ['The use of contraception was linked vicariously to promiscuity: Promiscuous women were linked to the use of contraception, multiple abortions and disease or infections.', ['Human2', 'Human5'], 19, 'Human5'], '1': ['Various sources attest that elevated mortality stemming from conflict is due more to population displacement, deficiencies of clean water and sanitation, exposure to disease, and public-health failures rather than to direct blows from violence.', ['llama2', 'mistral'], 10, 'llama2'], '2': ['Wind turbine foundations may act as artificial reefs, which could increase both the number of shellfish and the animals that feed on them, including other fish and marine mammals.', ['Human6', 'Human4'], 6, 'Human6'], '3': ['Civilians may also expand agricultural production due to cuts in a stable food supply.', ['Human7', 'Human4'], 11, 'Tie'], '4': ['Civilians may also expand agricultural production due to cuts in a stable food supply.', ['llama2', 'Human7'], 11, 'Tie'], '5': ['Borrowing food was observed to be the first step to mitigate the adverse effect of food insecurity at the household level in Yemen.', ['Human1', 'Human2'], 15, 'Human2'], '6': ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.', ['Human5', 'Human2'], 1, 'Human2'], '7': ['The direct and indirect effects from offshore wind farm development have been less well documented, but they include similar risks to bird and bat collisions [16,17]; disruption of marine mammal corridors [15] as well as harm to marine mammals, fish, and sea turtles from construction of bottom-mounted turbine towers [18]; the potential for scour and sediment resuspension around the foundations of bottom-mounted wind turbines [19]; and some evidence of displacement or barrier effects because of the presence of large offshore wind farms.', ['Human2', 'Human5'], 8, 'Human5'], '8': ['I had vaginal discharge four months ago and I used a traditional medicine it stopped.', ['llama3', 'llama2'], 20, 'Tie'], '9': ['The study shows that the cultivation of crops, a critical aspect of food security, is gravely under threat given low cultivation of crops as a result of BH atrocities.', ['Human4', 'Human2'], 9, 'Human2'], '10': ['The prompt acceleration of food aid pledges and deliveries once the media story on the famine broke, even though the worst of the crisis was over by then, and the poorer response to non-food emergency needs, which received less press attention, lends weight to another familiar hypothesis: that one of these non-humanitarian criteria is media pressure.', ['Human6', 'mistral'], 2, 'Human6'], '11': ['For me, when I got married and my wife was pregnant, I registered her in general hospital, and also in a traditional Centre. Because my understanding is that, there are medications in the hospital and also another type of medications from the traditional.', ['mistral', 'Human2'], 17, 'mistral'], '12': ['Civilians may also expand agricultural production due to cuts in a stable food supply.', ['Human2', 'llama2'], 11, 'Tie'], '13': ['Various sources attest that elevated mortality stemming from conflict is due more to population displacement, deficiencies of clean water and sanitation, exposure to disease, and public-health failures rather than to direct blows from violence.', ['Human1', 'Human2'], 10, 'Human1'], '14': ['Even, we do not want to be uncovered so that our private parts do not be seen.', ['Human1', 'llama3'], 18, 'Human1'], '15': ['The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out elsewhere (1996), the failure of these programmes has to do with the fact that in spite of the majority of them targeting farming, the serious stru ...
# {'0': ['However, wars have been waged to reduce demographic pressures arising from the scarcity of arable land, the clearest example being the move to acquire Lebensraum (living space) that motivated Nazi Germany aggression toward Poland and Eastern Europe.', ['Human4', 'Human7'], 7, 'Human4'], '1': ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.', ['Human4', 'Human5'], 1, 'Tie'], '2': ['Civilians may also expand agricultural production due to cuts in a stable food supply.', ['llama3', 'Human1'], 11, 'llama3'], '3': ['The prompt acceleration of food aid pledges and deliveries once the media story on the famine broke, even though the worst of the crisis was over by then, and the poorer response to non-food emergency needs, which received less press attention, lends weight to another familiar hypothesis: that one of these non-humanitarian criteria is media pressure.', ['Human3', 'Human6'], 2, 'Human3'], '4': ['The prompt acceleration of food aid pledges and deliveries once the media story on the famine broke, even though the worst of the crisis was over by then, and the poorer response to non-food emergency needs, which received less press attention, lends weight to another familiar hypothesis: that one of these non-humanitarian criteria is media pressure.', ['Human7', 'Human5'], 2, 'Human7'], '5': ['Even, we do not want to be uncovered so that our private parts do not be seen.', ['Human5', 'mistral'], 18, 'Human5'], '6': ['Even, we do not want to be uncovered so that our private parts do not be seen.', ['Human7', 'Human3'], 18, 'Tie'], '7': ['For me, when I got married and my wife was pregnant, I registered her in general hospital, and also in a traditional Centre. Because my understanding is that, there are medications in the hospital and also another type of medications from the traditional.', ['Human5', 'llama2'], 17, 'Human5'], '8': ['I had vaginal discharge four months ago and I used a traditional medicine it stopped.', ['llama3', 'Human5'], 20, 'Tie'], '9': ['Wind turbine foundations may act as artificial reefs, which could increase both the number of shellfish and the animals that feed on them, including other fish and marine mammals.', ['mistral', 'llama2'], 6, 'mistral'], '10': ['On the supply side, both Huthi/Saleh forces and the Hadi government and its Saudi-led coalition allies repeatedly have hindered the movement of aid and commercial goods to the population. Huthi/Saleh violations are most egregious in the city of Taiz, where their fighters have enforced a full or partial blockade since 2015, with devastating humanitarian consequences. They routinely interfere with the work of humanitarians, at times demanding the diversion of aid to themselves or denying aid workers access to populations in need, revoking visas or even detaining them. They heavily tax all imports into their areas in part to finance the war effort and also run a black market in fuel, enriching military elites while driving prices up for transport of vital commodities.', ['Human4', 'Human1'], 13, 'Human4'], '11': ['The prompt acceleration of food aid pledges and deliveries once the media story on the famine broke, even though the worst of the crisis was over by then, and the poorer response to non-food emergency needs, which received less press attention, lends weight to another familiar hypothesis: that one of these non-humanitarian criteria is media pressure.', ['llama2', 'Human4'], 2, 'llama2'], '12': ['Even, we do not want to be uncovered so that our private parts do not be seen.', ['Human4', 'llama3'], 18, 'Tie'], '13': ['The failure of programmes to reintegrate people into production implemented in the 1990s within the framework of the implementation of the 1992 Peace Accords forced many former combatants to resort to criminal and antisocial behaviour. As we have pointed out elsewhere (1996), the failur ...

# %%
# demonstrate that 1: contains all of the instances of sentence 1 from all files
sentence_data[1]
# Out:
# [['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['llama2', 'Human4'],
#   1,
#   'Human4'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human7', 'Human3'],
#   1,
#   'Human3'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['llama3', 'Human6'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['mistral', 'Human4'],
#   1,
#   'mistral'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human6', 'Human2'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human7', 'Human6'],
#   1,
#   'Human6'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['llama3', 'llama2'],
#   1,
#   'llama3'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human3', 'Human4'],
#   1,
#   'Human3'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['mistral', 'llama2'],
#   1,
#   'mistral'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['llama2', 'Human3'],
#   1,
#   'Human3'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human7', 'Human5'],
#   1,
#   'Human7'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['mistral', 'Human3'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['llama3', 'mistral'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human3', 'Human2'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human7', 'llama3'],
#   1,
#   'llama3'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['llama3', 'Human5'],
#   1,
#   'llama3'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human1', 'Human3'],
#   1,
#   'Human3'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human4', 'Human2'],
#   1,
#   'Human2'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human3', 'Human6'],
#   1,
#   'Human6'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human1', 'llama3'],
#   1,
#   'llama3'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human2', 'llama3'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['llama2', 'Human2'],
#   1,
#   'Human2'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['llama2', 'Human7'],
#   1,
#   'Human7'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human7', 'Human2'],
#   1,
#   'Human2'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human1', 'Human2'],
#   1,
#   'Human1'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human5', 'Human1'],
#   1,
#   'Human1'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human3', 'Human5'],
#   1,
#   'Human3'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human5', 'mistral'],
#   1,
#   'mistral'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['mistral', 'Human2'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human6', 'Human5'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human5', 'Human2'],
#   1,
#   'Human2'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['llama3', 'Human4'],
#   1,
#   'llama3'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['mistral', 'Human7'],
#   1,
#   'mistral'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human4', 'Human1'],
#   1,
#   'Human1'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human6', 'Human1'],
#   1,
#   'Human6'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['llama2', 'Human6'],
#   1,
#   'Human6'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human4', 'Human5'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['mistral', 'Human6'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human1', 'Human7'],
#   1,
#   'Tie'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['mistral', 'Human1'],
#   1,
#   'Human1'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human1', 'llama2'],
#   1,
#   'Human1'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human6', 'Human4'],
#   1,
#   'Human6'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human7', 'Human4'],
#   1,
#   'Human7'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human5', 'llama2'],
#   1,
#   'llama2'],
#  ['It is expected that both ecological and social compensation measures improve the overall acceptance of a local infrastructure, thus anchoring the latter within the surrounding community.',
#   ['Human3', 'llama3'],
#   1,
#   'Tie']]

# %% [markdown]
# ### Perform ELO for each of the twenty sentences' dfs to determine ground truth

# %%
# ELO rating update functions from Dr. ChatGPT
def update_elo(winner_elo, loser_elo, k=32):
    expected_winner = 1 / (1 + 10 ** ((loser_elo - winner_elo) / 400))
    expected_loser = 1 - expected_winner
    winner_elo += k * (1 - expected_winner)
    loser_elo += k * (0 - expected_loser)
    return winner_elo, loser_elo

def calculate_elo_for_sentence(sentence_id, comparisons):
    elo_ratings = {labeler: 1000 for labeler in labelers}
    
    # process comparisons for this sentence ID
    for value in comparisons:
        sentence, labelers_pair, _, winner = value
        if winner != "Tie":
            loser = labelers_pair[1] if winner == labelers_pair[0] else labelers_pair[0]
            elo_ratings[winner], elo_ratings[loser] = update_elo(elo_ratings[winner], elo_ratings[loser])
    
    # prepare data for DataFrame
    elo_df_data = {'sentence_start': [sample_sentences[sentence_id]]}
    for labeler in labelers:
        elo_df_data[labeler] = [elo_ratings[labeler]]
    elo_df_data['winner'] = [max(elo_ratings, key=elo_ratings.get)]
    
    return pd.DataFrame(elo_df_data)  # return DF of the scores/winners for each sentence

# %%
# elo calculations for all 20 sentences
sentence_dfs = []
for sentence_id, comparisons in sentence_data.items():
    sentence_dfs.append(calculate_elo_for_sentence(sentence_id, comparisons))

# concatenate DFs
final_df = pd.concat(sentence_dfs, ignore_index=True)
final_df.index = range(1, len(final_df) + 1)
final_df.index.name = 'sentence ID'

# %% [markdown]
# ### Display results

# %%
# Display the final DataFrame
pd.set_option('display.max_columns', None)
pd.set_option('display.width', None)
pd.set_option('display.max_colwidth', None)
print(final_df.iloc[:,1:])  # ignore sentence column
# Out:
#                   llama2       llama3      mistral       Human1       Human2  \
# sentence ID
# 1             911.752855  1069.140509  1037.010242  1034.104691  1034.671978
# 2            1029.529978   970.329772  1031.515572   892.285353  1116.109299
# 3            1024.852354   891.709846   952.246685   915.193939  1013.844112
# 4            1015.636074  1047.552381  1043.942990   930.772495  1045.782044
# 5             900.194717   918.843927   922.947856  1080.443476   956.008924
# 6             878.537629   956.446692   975.499404  1029.875274  1016.208313
# 7             945.260318   892.730461  1001.992705   986.977424  1073.525225
# 8             958.532522   890.639909   892.192046  1100.599298  1016.607988
# 9            1059.591856   996.927805   969.139095  1023.341983  1057.836703
# 10            910.291110   914.146934   918.780711  1064.497773  1053.878049
# 11            984.813125  1032.068295   979.976382   986.207464  1018.239577
# 12            894.118670   971.149825   988.281134   996.722884   973.812844
# 13            959.616317   907.049753   918.264838   973.934412  1018.031879
# 14            895.503578  1065.143383  1029.298721   949.735897  1031.315452
# 15            942.206942   902.352690   928.313180   955.722737  1083.554709
# 16            878.069019   967.852170   932.182447  1071.076747   989.861458
# 17           1010.859927  1080.512014  1038.507999  1017.999660   909.114977
# 18            992.674367  1009.226140  1043.532433   949.987216   890.016897
# 19            903.864710   921.507935   890.647800   996.982757  1036.956425
# 20           1013.872742  1015.436777  1042.175442   915.847701   878.969055
#
#                   Human3       Human4       Human5       Human6       Human7  \
# sentence ID
# 1            1051.936236   917.400986   900.805485  1069.639793   973.537226
# 2            1002.822998  1007.978252   893.267456  1029.467455  1026.693866
# 3            1030.654966  1074.018800  1072.251349   987.644240  1037.583709
# 4             988.867714  1061.502990   888.854041  1008.518745   968.570524
# 5            1056.112468  1018.733769  1057.605268  1098.636241   990.473355
# 6            1108.090782   931.891405  1009.144032  1076.656600  1017.649867
# 7             904.796554  1117.245470   987.208971  1089.943263  1000.319609
# 8            1088.093654  1038.749423  1014.731416  1041.738700   958.115045
# 9            1071.422562   982.754543   874.219830   906.225496  1058.540127
# 10            984.261193  1123.241146  1015.071201   999.660234  1016.171650
# 11            998.836393   984.000000   998.656541  1004.101776  1013.100447
# 12           1053.927802  1093.400701   893.259736  1094.764132  1040.562272
# 13           1093.988419  1070.079943  1066.361940  1012.580464   980.092036
# 14            969.068005   984.615751  1070.535423  1093.562902   911.220888
# 15           1001.785981  1069.965455  1060.213985  1030.103942  1025.780379
# 16           1036.935746   976.481948  1026.786628  1026.120647  1094.633189
# 17            997.640614   927.758995   929.635144  1083.644950  1004.325720
# 18            999.929568  1032.740997   992.364390  1065.828416  1023.699575
# 19           1085.189060  1037.897856  1057.365287  1044.282124  1025.306045
# 20           1027.203236  1026.648258  1025.156000  1044.394993  1010.295795
#
#              winner
# sentence ID
# 1            Human6
# 2            Human2
# 3            Human4
# 4            Human4
# 5            Human6
# 6            Human3
# 7            Human4
# 8            Human1
# 9            Human3
# 10           Human4
# 11           llama3
# 12           Human6
# 13           Human3
# 14           Human6
# 15           Human2
# 16           Human7
# 17           Human6
# 18           Human6
# 19           Human3
# 20           Human6

# %% [markdown]
# ### Save as a csv

# %%
# Save the final DataFrame to a CSV file
final_df.to_csv('final_elo_rankings.csv', index=False)
